# %% [markdown]
# ### **DATA INGESTATION**

# %%
import pandas as pd
import numpy as np

# %%
import os

print(os.listdir())
# Out:
# ['Experiment.ipynb']

# %%
print(os.getcwd())
# Out:
# c:\Users\user\HEALTH PROJECT\Notebook

# %%
data_path = r"C:\Users\user\HEALTH PROJECT\Data\Health Data.csv"

data = pd.read_csv(data_path)
data.head()
# Out:
#   patient_id            encounter_timestamp  age gender ethnicity  \
# 0    P300000  2025-01-01 09:06:00.000000000   69      F     ASIAN
# 1    P300001  2025-01-01 18:00:05.609198291   53      F     White
# 2    P300002  2025-01-01 07:28:11.218396582   57      F    Indian
# 3    P300003  2025-01-02 04:23:16.827594873   18      M     White
# 4    P300004  2025-01-02 00:25:22.436793164   69      M     Mixed
#
#    income_level education_level employment_status smoking_status  \
# 0          High       Secondary          Employed        current
# 1           Low         College           Retired            yes
# 2  Upper-Middle        Bachelor        Unemployed              0
# 3  Upper-Middle    Postgraduate          Employed              0
# 4  Upper-Middle       Secondary           Retired             no
#
#   alcohol_consumption  ...   department  length_of_stay  procedures_count  \
# 0            68 units  ...      gen med             2.6                 1
# ...

# %%
data.tail()
# Out:
#      patient_id            encounter_timestamp  age gender  ethnicity  \
# 3995    P900015  2025-10-24 13:55:40.882885148   65      M      black
# 3996    P900016  2025-03-01 08:01:23.542096004   47      M      ASIAN
# 3997    P900017  2025-08-24 22:12:04.421211360   65      F  CARIBBEAN
# 3998    P900018  2025-01-26 11:04:36.920331741   51      F      White
# 3999    P900019  2025-01-25 13:43:40.828348831   79      F   hispanic
#
#       income_level education_level employment_status smoking_status  \
# 3995          High        Bachelor           Retired              0
# 3996           Low        Bachelor          Employed             no
# 3997  Lower-Middle         College           Retired        current
# 3998           Low         Primary           Retired             no
# 3999           NaN       Secondary           Retired             no
#
#      alcohol_consumption  ...        department  length_of_stay  \
# 3995                  14  ...  General Medicine            7.00
# ...

# %%
print(data.columns)
# Out:
# Index(['patient_id', 'encounter_timestamp', 'age', 'gender', 'ethnicity',
#        'income_level', 'education_level', 'employment_status',
#        'smoking_status', 'alcohol_consumption', 'physical_activity',
#        'sleep_hours', 'diet_score', 'bmi', 'systolic_bp', 'diastolic_bp',
#        'heart_rate', 'blood_sugar_fasting', 'cholesterol_total',
#        'admission_type', 'department', 'length_of_stay', 'procedures_count',
#        'medications_count', 'complications', 'readmission_30days',
#        'total_treatment_cost', 'patient_satisfaction_score',
#        'discharge_disposition', 'follow_up_appointment_scheduled'],
#       dtype='object')
