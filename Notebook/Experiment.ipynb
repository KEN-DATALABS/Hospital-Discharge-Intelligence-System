# %% [markdown]
# ### **DATA INGESTATION**

# %%
pip install matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (3.11.0)
# Requirement already satisfied: seaborn in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=9 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

print(os.listdir())
# Out:
# ['Experiment.ipynb']

# %%
print(os.getcwd())
# Out:
# c:\Users\user\HEALTH PROJECT\Notebook

# %%
try:
    data_path = r"C:\Users\user\HEALTH PROJECT\Data\Health Data.csv"
    data = pd.read_csv(data_path)
    data.head()
except FileNotFoundError:
    print('File not found, Please check the path and try again')

# %%
data.tail()
# Out:
#      patient_id            encounter_timestamp  age gender  ethnicity  \
# 3995    P900015  2025-10-24 13:55:40.882885148   65      M      black
# 3996    P900016  2025-03-01 08:01:23.542096004   47      M      ASIAN
# 3997    P900017  2025-08-24 22:12:04.421211360   65      F  CARIBBEAN
# 3998    P900018  2025-01-26 11:04:36.920331741   51      F      White
# 3999    P900019  2025-01-25 13:43:40.828348831   79      F   hispanic
#
#       income_level education_level employment_status smoking_status  \
# 3995          High        Bachelor           Retired              0
# 3996           Low        Bachelor          Employed             no
# 3997  Lower-Middle         College           Retired        current
# 3998           Low         Primary           Retired             no
# 3999           NaN       Secondary           Retired             no
#
#      alcohol_consumption  ...        department  length_of_stay  \
# 3995                  14  ...  General Medicine            7.00
# 3996             4 units  ...  General Medicine            7.34
# 3997                  20  ...            Cardio            4.60
# 3998                  32  ...        cardiology            5.49
# 3999                   3  ...  General Medicine            5.33
#
#       procedures_count  medications_count complications  readmission_30days  \
# 3995                 3                6.0           0.0                   0
# 3996                 2                4.0           0.0                   0
# 3997                 3                4.0           NaN                   0
# 3998                 4                5.0           1.0                   0
# 3999                 1                4.0           NaN                   0
#
#       total_treatment_cost  patient_satisfaction_score discharge_disposition  \
# 3995               4195.97                           7       Skilled Nursing
# 3996               3588.46                           6                  Home
# 3997               7039.02                           8                  Home
# 3998               7721.82                           6                  Home
# 3999               4705.29                           6       Skilled Nursing
#
#      follow_up_appointment_scheduled
# 3995                               1
# 3996                               1
# 3997                               1
# 3998                               1
# 3999                               1
#
# [5 rows x 30 columns]

# %%
print(data.columns.tolist().upper())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print(data.columns.tolist().upper())
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
print(len(data.columns))
# Out:
# 30

# %%
shape = data.shape
print(f"The data contains {shape[0]} rows and {shape[1]} columns.")
# Out:
# The data contains 4000 rows and 30 columns.

# %%
data.dtypes
# Out:
# patient_id                          object
# encounter_timestamp                 object
# age                                  int64
# gender                              object
# ethnicity                           object
# income_level                        object
# education_level                     object
# employment_status                   object
# smoking_status                      object
# alcohol_consumption                 object
# physical_activity                  float64
# sleep_hours                        float64
# diet_score                           int64
# bmi                                float64
# systolic_bp                         object
# diastolic_bp                       float64
# heart_rate                         float64
# blood_sugar_fasting                float64
# cholesterol_total                   object
# admission_type                      object
# department                          object
# length_of_stay                     float64
# procedures_count                     int64
# medications_count                  float64
# complications                      float64
# readmission_30days                   int64
# total_treatment_cost               float64
# patient_satisfaction_score           int64
# discharge_disposition               object
# follow_up_appointment_scheduled      int64
# dtype: object
